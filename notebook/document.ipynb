# %% [markdown]
# ### Data Ingestion

# %%
###Document Datastructure

from langchain_core.documents import Document

# %%
doc=Document(
    page_content="this is the main text contrent I am using to create RAG",
    metadata={
        "source":"example.txt",
        "pages":1,
        "author":"Shivam Gupta",
        "date_created":"01.01.2026"
    }
)
doc
# Out:
# Document(metadata={'source': 'example.txt', 'pages': 1, 'author': 'Shivam Gupta', 'date_created': '01.01.2026'}, page_content='this is the main text contrent I am using to create RAG')

# %%
### Create a simple txt file

import os
os.makedirs("../data/text_files",exist_ok=True)

# %%
sample_texts={
    "../data/text_files/file1.txt":"""This is file 1""",
    "../data/text_files/file2.txt":"""This is file 2"""
}

for filepath,content in sample_texts.items():
    with open(filepath,'w',encoding="utf-8") as f:
        f.write(content)

print("Sample files created!")
# Out:
# Sample files created!

# %%
### Reading Text Files
#from langchain.document_loaders import TextLoader

from langchain_community.document_loaders import TextLoader

loader=TextLoader("../data/text_files/file1.txt",encoding="utf-8")
document=loader.load()
print(document)
# Out:
# [Document(metadata={'source': '../data/text_files/file1.txt'}, page_content='This is file 1')]

# %%
### Directory Loader
### Reading all text files at once

from langchain_community.document_loaders import DirectoryLoader

### load all text files from directory
dir_loader=DirectoryLoader(
    "../data/text_files",
    glob="**/*.txt", ## pattern Matching
    loader_cls= TextLoader, ## LoaderClass
    loader_kwargs={'encoding':"utf-8"},
    show_progress=False
)

documents=dir_loader.load()
documents
# Out:
# [Document(metadata={'source': '..\\data\\text_files\\file1.txt'}, page_content='This is file 1'),
#  Document(metadata={'source': '..\\data\\text_files\\file2.txt'}, page_content='This is file 2')]

# %%
### Directory Loader
### Load all pdf's

from langchain_community.document_loaders import PyPDFLoader, PyMuPDFLoader

dir_loader=DirectoryLoader(
    "../data/pdfs",
    glob="**/*.pdf",
    loader_cls=PyMuPDFLoader,
    
    show_progress=False
)

pdf_documents=dir_loader.load()
pdf_documents

# %%
type(pdf_documents)
type(pdf_documents[0])
# Out:
# list

# %%
### Directory Loader
### Load CSV Files

from langchain_community.document_loaders import CSVLoader

dir_loader=DirectoryLoader(
    "../data/csv",
    glob="**/*.csv",
    loader_cls=CSVLoader,
    
    show_progress=False
)

csv_files=dir_loader.load()
csv_files
# Out:
# [Document(metadata={'source': '..\\data\\csv\\LLM_Debugging_Tool_Guide.csv', 'row': 0}, page_content='Phase 4 – Polish & Deploy: Weeks 5–6\n: '),
#  Document(metadata={'source': '..\\data\\csv\\LLM_Debugging_Tool_Guide.csv', 'row': 1}, page_content='Phase 4 – Polish & Deploy: \n: '),
#  Document(metadata={'source': '..\\data\\csv\\LLM_Debugging_Tool_Guide.csv', 'row': 2}, page_content='Phase 4 – Polish & Deploy: Step\n: Interview tip'),
#  Document(metadata={'source': '..\\data\\csv\\LLM_Debugging_Tool_Guide.csv', 'row': 3}, page_content='Phase 4 – Polish & Deploy: Feedback loop\n: SQLite requires zero infrastructure — no Docker service, no credentials. Perfect for a portfolio project. Swap to Postgres only when you actually need concurrent writes.'),
# ...
